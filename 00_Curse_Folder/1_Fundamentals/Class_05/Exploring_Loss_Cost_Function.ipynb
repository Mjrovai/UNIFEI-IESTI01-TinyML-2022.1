# %% [markdown]
# <a href="https://colab.research.google.com/github/Mjrovai/UNIFEI-IESTI01-TinyML-2021.2/blob/main/00_Curse_Folder/1_Fundamentals/Class_05/Exploring_Loss_Cost_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring_Loss

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Define input data and target data

# %%
X = [-1, 0, 1, 2, 3, 4]
Y = [-3, -1, 1, 3, 5, 7]

# %%
type(X)
# Out:
# list

# %% [markdown]
# Plot data

# %%
plt.scatter(X, Y, color='red', label='Y')
plt.axis([-1,5,-5,8])
plt.title('Data')
plt.xlabel('X (input data)')
plt.ylabel('Y (target)')
plt.legend(loc='upper left')
plt.grid()

# %%
plt.plot(X, Y, color='red', marker='o', label='Y')
plt.axis([-1,5,-5,8])
plt.title('Data')
plt.xlabel('X (input data)')
plt.ylabel('Y (target)')
plt.legend(loc='upper left')
plt.grid()

# %% [markdown]
# Edit parameters (w and b) to try different loss measurements.
# - Rerun the cells when done
# - Your Y will be calculated as: Y=w*X+b,
#
# Example: if w=3, and b=-1, then: Y=3x-1

# %%
w = 3
b = -1

# %% [markdown]
# Calculate and plot Y_hat

# %%
Y_hat = [] 

for Xi in X:
  Yi = (w*Xi)+b
  Y_hat.append(Yi)
  print(Y_hat)
print("") 
print("Real Y is " + str(Y))
print("My Y is   " + str(Y_hat))
# Out:
# [-4]
# [-4, -1]
# [-4, -1, 2]
# [-4, -1, 2, 5]
# [-4, -1, 2, 5, 8]
# [-4, -1, 2, 5, 8, 11]
#
# Real Y is [-3, -1, 1, 3, 5, 7]
# My Y is   [-4, -1, 2, 5, 8, 11]

# %%
plt.plot(X, Y, color='red', marker='o', label='Y')
plt.plot(X, Y_hat, color='blue', marker='o', label='predictions')
plt.axis([-1,5,-5,15])
plt.title('Predictions')
plt.xlabel('X (input data)')
plt.ylabel('Y (output)')
plt.legend(loc='upper left')
plt.grid()

# %% [markdown]
# Let's calculate the loss

# %%
len(Y)
# Out:
# 6

# %%
total_squared_error = 0
n = len(Y)
for i in range(0, n):
  squared_error = (Y[i] - Y_hat[i]) ** 2
  total_squared_error += squared_error
  print(total_squared_error)
print("")
print("My total loss is: {:.2f}".format(total_squared_error))
# Out:
# 1
# 1
# 2
# 6
# 15
# 31
#
# My total loss is: 31.00

# %% [markdown]
# Let's calculate the MSE (Mean Squared Error) that is typical in Regression problems

# %%
print("My MSE loss is: {:.2f}".format((1/n)*(total_squared_error)))
# Out:
# My MSE loss is: 5.17

# %% [markdown]
# Criating a function

# %%
def calc_plot_error (X, Y, w, b):
    Y_hat = [] 
    for Xi in X:
        Yi = (w*Xi)+b
        Y_hat.append(Yi)

    total_squared_error = 0
    n = len(Y)
    for i in range(0, n):
        squared_error = (Y[i] - Y_hat[i]) ** 2
        total_squared_error += squared_error
    
    MSE = (1/n)*(total_squared_error)
    print("MSE is: {:.2f}".format(MSE))
    plt.plot(X, Y, color='red', marker='o', label='Y')
    plt.plot(X, Y_hat, color='blue', marker='o', label='predictions')
    plt.axis([-1,5,-5,15])
    plt.title('Predictions')
    plt.xlabel('X (input data)')
    plt.ylabel('Y (output)')
    #plt.legend(loc='upper left')
    plt.grid()

    return MSE

# %%
calc_plot_error (X, Y, w=2, b=-2)
# Out:
# MSE is: 1.00
# 1.0

# %% [markdown]
# Let's fix the parameter b and study w

# %%
b = -1
W_lst = [-2, -1, 0, 1, 2, 3, 4, 5, 6]
MSE_lst = []
for wi in W_lst:
    MSEi = calc_plot_error (X, Y, w=wi, b=b)
    MSE_lst.append(MSEi)
# Out:
# MSE is: 82.67
# MSE is: 46.50
# MSE is: 20.67
# MSE is: 5.17
# MSE is: 0.00
# MSE is: 5.17
# MSE is: 20.67
# MSE is: 46.50
# MSE is: 82.67

# %%
MSE_lst
# Out:
# [82.66666666666666,
#  46.5,
#  20.666666666666664,
#  5.166666666666666,
#  0.0,
#  5.166666666666666,
#  20.666666666666664,
#  46.5,
#  82.66666666666666]

# %%
plt.plot(W_lst, MSE_lst, color='orange', marker='o', label='error')
plt.title('Loss (Cost) Function')
plt.xlabel('W')
plt.ylabel('Loss');
